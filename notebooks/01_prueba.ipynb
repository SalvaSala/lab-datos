# %%
import pandas as pd
import seaborn as sns
import sys; sys.path.append("../src")
from utils import media_por


df = sns.load_dataset("penguins")
registros = df.to_dict("records")



print(f"El dataset tiene {df.shape[0]} filas y {df.shape[1]} columnas y {df['species'].nunique()} especies diferentes")
print(media_por(registros, "species","body_mass_g"))
# Out:
# {'mates': 6.67, 'lengua': 7.5}
# {'Ana': 8.0, 'Luis': 5.5, 'Eva': 8.0}
# El dataset tiene 344 filas y 7 columnas y 3 especies diferentes
# {'Adelie': 3700.66, 'Chinstrap': 3733.09, 'Gentoo': 5076.02}
